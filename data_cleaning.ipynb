# %%
import pandas as pd

# %%
bios = pd.read_csv("./Messy_Data/bios.csv")

# %%
bios.shape
# Out:
# (145500, 16)

# %% [markdown]
# ### So we have 145500 rows and 16 columns

# %%
bios.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# ...

# %% [markdown]
# ### Here we can see that most of the columns have NaN Values

# %% [markdown]
# ### Lets note down steps on which data needs to be cleaned.

# %% [markdown]
# - Get rid of bullet points in Used Names
# - Split height/weight
# - Parse out dates from 'Born' & 'Died' column
# - Parse out city, region, and country from 'Born' column
# - Get rid of extra column
# - Converting all column names into Snake Case

# %% [markdown]
# Before doing any changes to the dataset, lets make a copy of it and then proceed with the changes.

# %%
df = bios.copy()

# %%
df.head(10)
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
# 5                  Competed in Olympic Games  Male
# 6                  Competed in Olympic Games  Male
# 7                  Competed in Olympic Games  Male
# 8                  Competed in Olympic Games  Male
# 9                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# ...

# %% [markdown]
# ### Task-01: Get rid of bullet points in Used Names

# %% [markdown]
# As we can see that, column "Used name" has names with specific symbol "•". We want to remove those symbols and separate the names into a new column named "name"

# %% [markdown]
# Before that lets check if all the rows have that symbol

# %%
len(df)
# Out:
# 145500

# %%
len(df[df["Used name"].str.contains("•")])
# Out:
# 145500

# %% [markdown]
# Now lets remove that symbol

# %%
df['name'] = df['Used name'].str.replace("•", " ")

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# ...

# %% [markdown]
# ### Task-02: Split height/weight

# %%
df['height_cm'] = df['Measurements'].str.extract(r'(\d+ cm)')
df['weight_kg'] = df['Measurements'].str.extract(r'(\d+ kg)')

# %%
df.head(10)
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
# 5                  Competed in Olympic Games  Male
# 6                  Competed in Olympic Games  Male
# 7                  Competed in Olympic Games  Male
# 8                  Competed in Olympic Games  Male
# 9                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# ...

# %% [markdown]
# ### Now remove the units "cm" and "kg"

# %%
df['height_cm'] = pd.to_numeric(df['height_cm'].str.strip(' cm'), errors='coerce')
df['weight_kg'] = pd.to_numeric(df['weight_kg'].str.strip(' kg'), errors='coerce')

# %%
df.head(10)
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
# 5                  Competed in Olympic Games  Male
# 6                  Competed in Olympic Games  Male
# 7                  Competed in Olympic Games  Male
# 8                  Competed in Olympic Games  Male
# 9                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# ...

# %% [markdown]
# ### Task-03: Parse Out Dates from 'Born' and 'Died' columns

# %%
date_pattern = r'(\d+ \w+ \d{4}|\d{4}|\w+ \d{4})'
df['born_date'] = df['Born'].str.extract(date_pattern)
df['born_date'] = pd.to_datetime(df['born_date'], format="mixed", errors='coerce')

df['died_date'] = df['Died'].str.extract(date_pattern)
df['died_date'] = pd.to_datetime(df['died_date'], format="mixed", errors='coerce')

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# ...

# %% [markdown]
# ### Task-04: Parsing out location from Born Column

# %%
df['Born'].head()
# Out:
# 0          12 December 1886 in Bordeaux, Gironde (FRA)
# 1               1 April 1969 in Meulan, Yvelines (FRA)
# 2    13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3              11 May 1895 in Paris VIIIe, Paris (FRA)
# 4           17 April 1878 in Wandsworth, England (GBR)
# Name: Born, dtype: str

# %%
df[['location', 'country_code']] = df['Born'].str.extract(r'in (.*?) \((.*?)\)$')

# %%
df.head(10)
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
# 5                  Competed in Olympic Games  Male
# 6                  Competed in Olympic Games  Male
# 7                  Competed in Olympic Games  Male
# 8                  Competed in Olympic Games  Male
# 9                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# ...

# %% [markdown]
# ### Task-05: Getting rid of extra columns

# %%
df.columns
# Out:
# Index(['Roles', 'Sex', 'Full name', 'Used name', 'Born', 'Died', 'NOC',
#        'athlete_id', 'Measurements', 'Affiliations', 'Nick/petnames',
#        'Title(s)', 'Other names', 'Nationality', 'Original name', 'Name order',
#        'name', 'height_cm', 'weight_kg', 'born_date', 'died_date', 'location',
#        'country_code'],
#       dtype='str')

# %%
columns_needed = ['athlete_id', 'name', 'Sex', 'born_date', 'location', 'country_code', 'NOC', 'height_cm', 'weight_kg', 'died_date']

df_clean = df[columns_needed]

# %% [markdown]
# ### Task-06: Converting all column names into snake case

# %%
df_clean.columns = df_clean.columns.str.lower().str.replace(" ", "_")

# %%
df_clean.head()
# Out:
#    athlete_id                   name   sex  born_date  \
# 0           1  Jean-François Blanchy  Male 1886-12-12
# 1           2         Arnaud Boetsch  Male 1969-04-01
# 2           3           Jean Borotra  Male 1898-08-13
# 3           4        Jacques Brugnon  Male 1895-05-11
# 4           5           Albert Canet  Male 1878-04-17
#
#                          location country_code     noc  height_cm  weight_kg  \
# 0               Bordeaux, Gironde          FRA  France        NaN        NaN
# 1                Meulan, Yvelines          FRA  France      183.0       76.0
# 2  Biarritz, Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3              Paris VIIIe, Paris          FRA  France      168.0       64.0
# 4             Wandsworth, England          GBR  France        NaN        NaN
#
#    died_date
# 0 1960-10-02
# 1        NaT
# 2 1994-07-17
# 3 1978-03-20
# 4 1930-07-25

# %%
df_clean.to_csv('./Cleaned_Data/cleaned_bios.csv', index=False)
